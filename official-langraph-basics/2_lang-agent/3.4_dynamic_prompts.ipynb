# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass
from langchain.agents.middleware import dynamic_prompt, ModelRequest

@dataclass
class LanguageContext:
    user_language: str = "English"

@dynamic_prompt
def user_language_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on user role."""
    user_language = request.runtime.context.user_language
    base_prompt = "You are a helpful assistant."

    if user_language != "English":
        return f"{base_prompt} only responsd in {user_language}"
    elif user_language == "English":
        return base_prompt

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    context_schema=LanguageContext,
    middleware=[user_language_prompt]
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Irish")
)

print(response["messages"][-1].content)
# Out:
# Dia dhuit! Is mise ChatGPT agus is féidir liom cabhrú leat i ngaeilge agus i ngach ábhar eile. Cad é an rud atá uait inniu?
#
# Mar shampla, is féidir liom:
# - Míniú ar fhocail nó ar nathanna
# - Aistriúchán nó leagan Gaeilge ar théacs
# - Cabhair le scríbhneoireacht, gramadach, nó leagan amach téacs
# - Cúnamh le cód nó le freagra ar fhadhb theicniúil
# - Moltaí agus treoir maidir le taistil nó staidéir
#
# Cuir ceist orm agus déanfaimid é le chéile.

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hellow, how are you?")]},
    context=LanguageContext(user_language="French")
)

print(response["messages"][-1].content)
# Out:
# Bonjour ! Comment puis-je vous aider aujourd’hui ? Dites-moi ce que vous cherchez (traduction, résumé, explication, aide à un devoir, rédaction, idées, etc.) ou collez le texte et précisez l’action souhaitée.

# %%
# EOF
