# %%
# !uv show "langgraph-cli[inmem]"
# Out:
# error: unrecognized subcommand 'show'
#
#   tip: a similar subcommand exists: 'uv pip show'
#
# Usage: uv [OPTIONS] <COMMAND>
#
# For more information, try '--help'.
